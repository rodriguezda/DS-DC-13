# %% [markdown]
# # Class 14 - Starter Code
#
# Natural Language Processing and Topic Modeling

# %%
# spacy is used for pre-processing and traditional NLP
import spacy
from spacy.en import English
nlp_toolkit = English()

# Gensim is used for LDA and word2vec
from gensim.models.word2vec import Word2Vec

# %% [markdown]
# # Twitter Lab

# %% [markdown]
# In this exercise, we will compare some of the classical NLP tools from the last class with these more modern latent variable techniques.  We will do this by comparing information extraction on Twitter using two different methods.
#
# > NOTE:  There is a pre-existing file of captured tweets you can use.  It is located in the class repo for lesson-14.  However, you can also collect your own tweets following the instructions in twitter-instructions.md.

# %%
# Loading the twitter data
tweets = [unicode(tweet, errors='ignore') for tweet in \
          open('../../assets/dataset/captured-tweets.txt', 'r')]

# %% [markdown]
# # Part 1: Using `spacy`
#
# Use `spacy` to write a function to filter tweets down to those where Google is announcing a product. How might we do this? One way might be to identify verbs, where 'Google' is the noun and there is some action like 'announcing'

# %%
# Use spacy to parse each tweet
parsed_tweets = []
for tweet in tweets:
    parsed_tweets.append(nlp_toolkit(tweet))

# %% [markdown]
# ### 1.a
# Write a function that can take a sentence parsed by spacy and identify if it mentions a company named 'Google'. Remember,spacy can find entities and code them as ORG if they are a company.
#
# ### 1.b
# BONUS: Make this function work for any company.
#
# Hint: https://spacy.io/docs#examples-entities

# %%
# Write a function that can take a take a sentence parsed by `spacy` and 
# identify if it mentions a company named 'Google'. 
# Remember, `spacy` can find entities and code them `ORG` if they are a company.
def mentions_company(parsed, company='Google'):
    for entity in parsed.ents:
        if entity.text == company and entity.label_ == 'ORG':
            return True
    return False

# %%
# For each tweet, use parsed tweet to check your function
for i, parsed_tweet in enumerate(parsed_tweets):
    if mentions_company(parsed_tweet, 'Google'):
        print parsed_tweet
        if i>10:
            break
# Out:
# Google Play Gift Card Code
#
# Claim your Google Play Gift Card Code... https://t.co/ySYH1x5kQl #amazon #itunes #googl https://t.co/ayDI4X1FKO
#
# King of dark fantasy. Summon today. App Store: https://t.co/XeEuOEaXEG Google Play: https://t.co/vYQdbhrNEb #DarkSummoner

# %% [markdown]
# ### 1.c
# Write a function that can take a sentence parsed by spacy and return the verbs of the sentence (preferably lemmatized).
#
# Hint: https://spacy.io/docs#examples-pos-tags

# %%
# Write a function that can take a sentence parsed by `spacy` 
# and return the verbs of the sentence (preferably lemmatized)
def get_actions(parsed):
    actions = [el.lemma_ 
                for el in parsed 
                if el.pos == spacy.parts_of_speech.VERB
               ]
    return actions

# %%
# For each tweet, use parsed tweet to check your function
for i, parsed_tweet in enumerate(parsed_tweets):
    print get_actions(parsed_tweet)
    if i>10:
        break
# Out:
# [u'make']
# []
# []
# [u'google']
# []
# []
# [u'use', u'learn']
# [u'be', u'need', u'help', u'be', u'lack']
# []
# [u'claim']
# [u'come']
# []

# %% [markdown]
# ### 1.d
#
# For each tweet that mentions Google, parse it using spacy and print it out if the tweet has 'release' or 'announce' as a verb.

# %%
for i, parsed_tweet in enumerate(parsed_tweets):
    if mentions_company(parsed_tweet, 'Google'):
        actions = get_actions(parsed_tweet)
        if 'release' in actions or 'announce' in actions:
            print(parsed_tweet)
            
#some data culls as ampersand, we'll have to replace it
# Out:
# Google &amp; Ford rumored to announce partnership at CES https://t.co/zOgm1NjHhD https://t.co/Gzx81ujqVC
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/Qvmc34T5QA
#
# Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
# Google's Project Ara Spiral is expected to be released next year January https://t.co/prycPMuGsG
#
# #Lenovo And #Google To Officially Announce #ProjectTango On January 7 At CES https://t.co/04seCBKv16
#
# RT @GizmoChina: Lenovo And Google To Officially Announce Project Tango On January 7 At CES https://t.co/GNmL0uw9xl
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/6woe56G22Q
#
# Google and Ford to announce partnership on self-driving cars at CES - Fudzilla (blog) https://t.co/4hERVJ4zZK

# %% [markdown]
# ### 1.e
# Write a function that identifies countries.  HINT: the entity label for countries is GPE (or "GeoPolitical Entity").
#
# Hint: https://spacy.io/docs#annotation-ner

# %%
# Write a function that identifies countries - HINT: the entity label for 
# countries is GPE (or GeoPolitical Entity)
def mentions_country(parsed, country):
    for entity in parsed.ents:
        if entity.text == country and entity.label_ == 'GPE':
            return True
    return False

# %%
for i, parsed_tweet in enumerate(parsed_tweets):
    if mentions_country(parsed_tweet, 'Iran'):
        print parsed_tweet
        if i>1000:
            break
# Out:
# RT @f396: Iran blames America, Britain and 'Zionists' for Nimr execution - https://t.co/BwXEicgAOA via https://t.co/UjStGmTT2f
#
# RT @f396: Saudi Arabia severs diplomatic ties with Iran over embassy fire - https://t.co/r0iZugJa3v via https://t.co/UjStGmTT2f
#
# RT @f396: 'Iran has a long record in attacking foreign diplomatic missions,' Saudi ... - https://t.co/3gaSRB3osT via https://t.co/UjStGmTT2f
#
# # # # # Saudi Arabia cuts ties with Iran - Mail &amp; Guardian Online  https://t.co/vxCisN0Hrh

# %% [markdown]
# ### 1.f
# Re-run to find country tweets that discuss 'Iran' announcing or releasing.

# %%
for i, parsed_tweet in enumerate(parsed_tweets):
    if mentions_company(parsed_tweet, 'Iran'):
        actions = get_actions(parsed_tweet)
        if 'release' in actions or 'announce' in actions:
            print(parsed_tweet)
        else:
            print("nothing")

# %% [markdown]
# # Part 2: Using `gensim`
#
# Build a `word2vec` model of the tweets we have collected using `gensim`.

# %% [markdown]
# ### 2.a
# First take the collection of tweets and tokenize them using spacy.
# Think about how this should be done.
# Should you only use upper-case or lower-case?
# Should you remove punctuations or symbols?

# %%
# Lemmatize the verbs for easier searching and keep symbols and punctuations
split_tweets = [[x.text if x.pos != spacy.parts_of_speech.VERB else x.lemma_ 
                 for x in nlp_toolkit(t)] for t in tweets]

# %%
print tweets[0]
# Out:
# I made a(n) Small Tourmaline in Paradise Island! https://t.co/cAoW1b6DRc #Gameinsight #Androidgames #Android

# %%
print split_tweets[0]
# Out:
# [u'I', u'make', u'a(n', u')', u'Small', u'Tourmaline', u'in', u'Paradise', u'Island', u'!', u'https://t.co/cAoW1b6DRc', u'#', u'Gameinsight', u'#', u'Androidgames', u'#', u'Android', u'\n']

# %% [markdown]
# ### 2.b
# Build a word2vec model.
# Test the window size as well - this is how many surrounding words need to be used to model a word. What do you think is appropriate for Twitter?

# %%
# Build a `word2vec` model
model = Word2Vec(split_tweets, size=100, window=4, min_count=5, workers=4)

# %% [markdown]
# ### 2.c
# Test your word2vec model with a few similarity functions.
# Find words similar to 'Syria'.
# Find words similar to 'war'.
# Find words similar to 'Iran'.
# Find words similar to 'Verizon'.

# %%
model.most_similar(positive=['Verizon'])
# Out:
# [(u'Microsoft', 0.9997143745422363),
#  (u'after', 0.9997115135192871),
#  (u'iPhone', 0.9997094869613647),
#  (u'here', 0.9996896982192993),
#  (u'Xbox', 0.9996877908706665),
#  (u'6', 0.9996792674064636),
#  (u'call', 0.9996715784072876),
#  (u'4', 0.9996697902679443),
#  (u'Your', 0.9996682405471802),
#  (u'Black', 0.9996664524078369)]

# %%
model.most_similar(positive=['war'])
# Out:
# [(u'under', 0.9996192455291748),
#  (u'Facebook', 0.999558687210083),
#  (u'children', 0.9995566010475159),
#  (u'=', 0.9995386600494385),
#  (u'No', 0.9995381832122803),
#  (u'Syrian', 0.9995209574699402),
#  (u'+', 0.9995180368423462),
#  (u'new', 0.9994900822639465),
#  (u'Iraq', 0.9994814395904541),
#  (u'use', 0.9994798898696899)]

# %%
model.most_similar(positive=['war', 'Iran'])
# Out:
# [(u'opposition', 0.9995629787445068),
#  (u'Syria', 0.9995148777961731),
#  (u"'s", 0.9992072582244873),
#  (u'Paris', 0.99920654296875),
#  (u'defeat', 0.9990522861480713),
#  (u'=', 0.9988870024681091),
#  (u'|', 0.9988430738449097),
#  (u'https', 0.9988420605659485),
#  (u'HumanRights', 0.9988245368003845),
#  (u'android', 0.9988110065460205)]

# %%
model.most_similar(positive=['Iran'])
# Out:
# [(u'Syria', 0.9981015920639038),
#  (u'regime', 0.9979629516601562),
#  (u'opposition', 0.9974390268325806),
#  (u'Paris', 0.997266411781311),
#  (u'News', 0.9971316456794739),
#  (u'democratic', 0.9971151351928711),
#  (u'France', 0.9970508813858032),
#  (u'UK', 0.9969102144241333),
#  (u'defeat', 0.9968844652175903),
#  (u'StopExecutionsIran', 0.9967482089996338)]

# %%
model.most_similar(positive=['war', 'Iraq'])

# %% [markdown]
# # Part 3: Comparing `spacy` and `gensim`
# Filter tweets to those that mention 'Iran' or similar entities and 'war' or similar entities.

# %% [markdown]
# ### 3.a
# Using `spacy`

# %%
# Using spacy
for i, parsed_tweet in enumerate(parsed_tweets):
    if mentions_country(parsed_tweet, 'Iran') \
    or mentions_country(parsed_tweet, 'Iraq'):
        if 'attack' in get_actions(parsed_tweet) \
        or 'war' in parsed_tweet.text:
            print(parsed_tweet)
# Out:
# RT @f396: 'Iran has a long record in attacking foreign diplomatic missions,' Saudi ... - https://t.co/3gaSRB3osT via https://t.co/UjStGmTT2f
#
# RT @iran_policy: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his injur
#
# #Iran #News Starvation has become tool of war in #Syria https://t.co/8fvRtxinW2  https://t.co/JSyjMqjtnq
#
# #Iran provoked by U.S. into reacting angrily, then we claim they r evil. Iran not attacked another country for 400  https://t.co/3lTO2hgFPr
#
# RT @Mojahedineng: #Iran #News Starvation has become tool of war in #Syria https://t.co/F0NnT87DMc https://t.co/f3J70v47aL
#
# Iran-Saudi sectarian proxy wars set to explode, Israeli experts say - Middle East - Jerusalem Post
#
# RT @iran_policy: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualties
#
# RT @Mojahedineng: #Iran #News EUs foreign policy chief warned Iran on renewed tension with Saudi Arabia https://t.co/ifzIVcWwOV https://t.
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont
#
# #Iran #News EUs foreign policy chief warned Iran on renewed tension with Saudi Arabia https://t.co/cCbAr3MqsH  https://t.co/bVKAfxQZ1h
#
# RT @iran_policy: Ahmad Ramazan: #Iran regime no longer calls the shots in #Syria war. It has been superceded by Russia. #No2Rouhani #StopEx
#
# RT @4FreedominIran: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his in
#
# RT @4FreedominIran: Ahmad Ramazan: #Iran regime no longer calls the shots in #Syria war. It has been superceded by Russia. #No2Rouhani #Sto
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/TRshnC6sVU
#
# GOBE! Iran warns Nigeria to release Shiite leader El-Zakzaky - SEE https://t.co/SlvcQtk3vE
#
# RT @iran_policy: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his injur
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont
#
# RT @iran_policy: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualties
#
# RT @4FreedominIran: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualti
#
# Hhmmm. Iran claiming to have 'warned Nigeria' to release detained Shiite leader.... @afalli
#
# RT @Google_Kugle20: Looks like @HillaryClinton and Iran have similar strategies when an embassy is attacked... https://t.co/ACAueB4yVy
#
# RT @Dr_Rafizadeh: #Iran attacked the Egyptian embassy first, then the American, Denmark, British, and now the #Saudi embassy. Is there a tr
#
# RT @iran_policy: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualties
#
# RT @4FreedominIran: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his in
#
# RT @wikileaks: The cold war between #Saudi Arabia and #Iran that's tearing apart the Middle East, explained https://t.co/vyoUIDT994
#
# RT @iran_policy: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his injur
#
# RT @Mojahedineng: #Iran #News Saudi embassy in #tehran was attacked and damaged by Iranian regime mobs https://t.co/qTniZnBEw2 https://t.co
#
# RT @iran_policy: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualties
#
# RT @cerenomri: "Literally every US ally in Mideast is on brink of hot war w/ Iran, so we're going to release $100 billion to Iran this mont
#
# RT @4FreedominIran: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualti
#
# RT @4FreedominIran: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his in
#
# RT @IranNewsUpdate1: #Iran Inches toward Implementation but Still Raises the Ire of Critics https://t.co/SxZsUoNTca https://t.co/Kcnjsrta7C
#
# RT @wikileaks: The cold war between #Saudi Arabia and #Iran that's tearing apart the Middle East, explained https://t.co/vyoUIDT994
#
# RT @Amaka_Ekwo: El-Zakzaky: Iran issues final warning, says it hopes Nigerian govt takes wise action https://t.co/hHM9W1Cf7k
#
# RT @4FreedominIran: .@sanabarghzahedi: ... so #Iran IRGC Quds Force commander Qassem Soleimani went to Moscow to seek help in #Syria war ht
#
# RT @Doug_Bandow: When I think of #Iran and #SaudiArabia, I think of Kissinger's comment on the #Iraq-Iran war--too bad both can't lose.
#
# RT @NaziaAngel1993: #HappyNewYear to all leaders out there. Here are your war-spoils. #Syria #Iraq https://t.co/3EvenF5st5
#
# RT @iran_policy: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his injur
#
# RT @iran_policy: .@sanabarghzahedi: ... so #Iran IRGC Quds Force commander Qassem Soleimani went to Moscow to seek help in #Syria war https
#
# RT @Donyayeazad: #Iran #News Starvation has become tool of war in #Syria! https://t.co/u3Y2PY6uUg #children #unesco #No2Rouhani #AP https:/
#
# RT @iran_policy: .@sanabarghzahedi: ... so #Iran IRGC Quds Force commander Qassem Soleimani went to Moscow to seek help in #Syria war https
#
# RT @iran_policy: Ahmad Ramazan: #Iran regime no longer calls the shots in #Syria war. It has been superceded by Russia. #No2Rouhani #StopEx
#
# RT @iran_policy: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualties
#
# RT @4FreedominIran: Ahmad Ramazan: #Iran regime no longer calls the shots in #Syria war. It has been superceded by Russia. #No2Rouhani #Sto
#
# RT @iran_policy: Saleh Hamid: Right now many differences exist between #Iran regime + Russia in #Syria war. Iran feels it gives casualties
#
# RT @4FreedominIran: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his in
#
# RT @4FreedominIran: .@sanabarghzahedi: ... so #Iran IRGC Quds Force commander Qassem Soleimani went to Moscow to seek help in #Syria war ht
#
# RT @iran_policy: Saleh Hamid: In reality #Iran IRGC Quds Force Gen. Qassem Soleimani is now out of action in #Syria war following his injur
#
# RT @IraqiSecurity: Both Reuters &amp; AFP hinting that the mosques attacked in #Iraq were retaliation 4 #SheikhNimr.
#
# RT @NaziaAngel1993: #HappyNewYear to all leaders out there. Here are your war-spoils. #Syria #Iraq https://t.co/3EvenF5st5
#
# RT @Jamie_Woodward_: Archaeologists return to Iraq to study Neanderthals at Shanidar Cave as ISIS is pushed back https://t.co/Mo8VjHqaII ht
#
# RT @wikileaks: The cold war between #Saudi Arabia and #Iran that's tearing apart the Middle East, explained https://t.co/vyoUIDT994
#
# RT @iran_policy: .@sanabarghzahedi: ... so #Iran IRGC Quds Force commander Qassem Soleimani went to Moscow to seek help in #Syria war https
#
# RT @iran_policy: Ahmad Ramazan: #Iran regime no longer calls the shots in #Syria war. It has been superceded by Russia. #No2Rouhani #StopEx
#
# RT @wikileaks: The cold war between #Saudi Arabia and #Iran that's tearing apart the Middle East, explained https://t.co/vyoUIDT994
#
# AIPAC threatened Obama with war &amp; want to destroy Iran. https://t.co/X31MWxqaKM
#
# RT @arthurschwartz: Says the fake Vietnam combat vet who just voted to give $150 billion to Iran. #ValorThief  https://t.co/QAQXxcK3qa
#
# RT @wikileaks: The cold war between #Saudi Arabia and #Iran that's tearing apart the Middle East, explained https://t.co/vyoUIDT994
#
# RT @BiafraHerald: Iran: We have used all channels to warn Nigeria over Shiite leader https://t.co/nqLjxSJwx8 https://t.co/RY4tnumVm5

# %% [markdown]
# ### 3.b
# Using `gensim`

# %%
# Using gensim
for i, split_tweet in enumerate(split_tweets):
    similarity_to_iran = max([model.similarity('Iran', tok) for tok in split_tweet if tok in model.vocab]+[0])
    similarity_to_war = max([model.similarity('war', tok) for tok in split_tweet if tok in model.vocab]+[0])
    if similarity_to_iran > 0.999 and similarity_to_war > 0.999:
        print (similarity_to_iran, similarity_to_war)
        print ' '.join(split_tweet)
# Out:
# (0.99999999999999967, 0.99942548344164106)
# RT @f396 : Iran blame America , Britain and ' Zionists ' for Nimr execution - https://t.co/BwXEicgAOA via https://t.co/UjStGmTT2f
#
# (0.99999999999999967, 0.99942548344164106)
# RT @f396 : Saudi Arabia sever diplomatic ties with Iran over embassy fire - https://t.co/r0iZugJa3v via https://t.co/UjStGmTT2f
#
# (0.99999999999999967, 0.99942548344164106)
# RT @f396 : ' Iran have a long record in attack foreign diplomatic missions , ' Saudi ... - https://t.co/3gaSRB3osT via https://t.co/UjStGmTT2f
#
# (0.99999999999999967, 0.99914102868996546)
# Iran : 4 prisoners in Gohadasht Prison begin their second week of hunger Strike https://t.co/qldbF6bv3D # iraq # LeMonde # google
#
# (0.99999999999999967, 0.99961941183948189)
# RT @Donyayeazad : List of women execute under Rouhani regime ! https://t.co/Gr3BjFB5HW   # stopexecutioniran # No2Rouhani # Iran # Syria https://
#
# (0.99999999999999967, 0.99942087590630091)
# do nt let Rouhani , president of Execution visit 2 Europe . # Iran # Iranian # Italy # Europe https://t.co/Rgm5RcfCQi
#
# (0.99999999999999967, 0.99936954871388806)
# RT @AlArabiya_Eng : OPINION : Its shocking that # Saudi be view dubiously when # Iran have be find to assist al - Qaeda : @FaisalJAbbas https
#
# (0.99999999999999967, 0.99922417088860904)
# RT @iran_policy : Saleh Hamid : sever of Arab states ' ties with # Iran regime benefit Iranian &amp ; # Syria opposition movements . # SaudiArabia
#
# (0.99999999999999967, 0.99910151907576816)
# My nephew ( 8 ) believe that countries should cut ties with Saudi Arabia instead of with Iran .
#
# (0.99999999999999967, 0.99905123470367618)
# RT @iran_policy : Ahmad Ramazan : # Iran 's regime be anti - Arab and inhuman . # No2Rouhani # StopExecutionsIran https://t.co/1aXzAKvP4x
#
# (0.99999999999999967, 0.99953873544231364)
# RT @4FreedominIran : Saleh Hamid : Reason for high casualty rate of Afghan forces in # Syria = # Iran regime just send them for money without
#
# (0.99999999999999967, 0.99927921183599588)
# Headlines : Iran be at top . For country specific top trends visit : https://t.co/hKfGwUsRCD for more info https://t.co/TjggIOmVUK
#
# (0.99999999999999967, 0.99922886548833834)
# RT @4FreedominIran : be Hassan Rouhani a moderate ? know more about him ! https://t.co/Le0YPjQy3b # No2Rouhani # Iran # HumanRights # USA https://
#
# (0.99999999999999967, 0.99943496128591269)
# Saudi Arabia recruit Sunni allies in row with Iran
#
# (0.99999999999999967, 0.99922417088860904)
# Not everything be down . Gold rises on global fear # China # SaudiArabia # yellowmetal # Iran https://t.co/8tgOkw0QqR https://t.co/LOsLaYoyaA
#
# (0.99999999999999967, 0.99922417088860904)
# lead abusive , inhumane theocracies of the # MiddleEast , # Iran &amp ; # SaudiArabia , each as bad as the other , be have a ridiculous standoff
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Saleh Hamid : In reality # Iran IRGC Quds Force Gen. Qassem Soleimani be now out of action in # Syria war follow his injur
#
# (0.99999999999999967, 0.99942548344164106)
# # Iran and # Saudi Arabia : The Showdown between Islam 's Rival Powers , via @NewYorker https://t.co/8FBIqzPc9p
#
# (0.99999999999999967, 0.99947401253784762)
# RT @iran_policy : # Iran regime plan to forcibly turn Tehran church grounds into mosque
#
# (0.99999999999999967, 0.99932876603034504)
# RT @4FreedominIran : .@sanabarghzahedi : give # Iran regime 's casualties in # Syria , hegemony be now with Russia &amp ; this speak of change of ba
#
# (0.99999999999999967, 0.99961941183948189)
# List of women execute under Rouhani regime ! https://t.co/CZyK4SobMA   # humanRights # No2Rouhani # Iran # IranTalks https://t.co/yuYdvMvljf
#
# (0.99999999999999967, 0.99906123487561183)
# RT @carlbildt : It go without say that Iran gravely neglect its duties to protect Saudi diplomatic premises during last 48 hours or s
#
# (0.99999999999999967, 0.99921183420743986)
# RT @4FreedominIran : .@fholande Rouhani 's record ? 3 executions per day ! do n't be his partner in crime ! # Iran # No2Rouhani # Paris # UK https:/
#
# (0.99999999999999967, 0.99923803058456784)
# UN chief calls on Iran , Saudi Arabia to avoid further exacerbate tensions after executions https://t.co/5dlmDA8SU3 # UN
#
# (0.99999999999999967, 0.99933164598444491)
# RT @ahmmadhasani : .@fholande Rouhani wo n't drink wine , but will kill 3 people every day ! # Iran # France # Europe # MiddleEast # USA https://t.co
#
# (0.99999999999999967, 0.99999999999999989)
# # Iran # News Starvation have become tool of war in # Syria https://t.co/8fvRtxinW2   https://t.co/JSyjMqjtnq
#
# (0.99999999999999967, 0.99947401253784762)
# RT @abasnadimy : Saudi cuts ties with Iran , expel Tehran envoys https://t.co/ULAFmIjfwO   # No2Rouhani # Iran # IranFreedom # terrorism https://
#
# (0.99999999999999967, 0.9990377009524799)
# RT @CodeAud : Arab twitter users call for boycott # Iran , # Iranian products @MarianneSansum @ArRuple @JAmy208 @tpel78 @mkmknani
#
# (0.99999999999999967, 0.999251034760959)
# RT @iran_policy : Saleh Hamid : # Iran regime refuse to give info on IRGC Gen. Qassem Soleimani who be injure in # Syria . # No2Rouhani # StopE
#
# (0.99999999999999967, 0.99938832499374319)
# # Iran provoke by U.S. into react angrily , then we claim they r evil . Iran not attack another country for 400   https://t.co/3lTO2hgFPr
#
# (0.99999999999999967, 0.99999999999999989)
# RT @Mojahedineng : # Iran # News Starvation have become tool of war in # Syria https://t.co/F0NnT87DMc https://t.co/f3J70v47aL
#
# (0.99999999999999967, 0.99901304573302852)
# RT @Opinionriver : Iran warn Nigeria on Zakzaky , Hopes Buhari Government Would Adopt ' Wise Action ' https://t.co/GvAERsexa2 https://t.co/cnT
#
# (0.99999999999999967, 0.99920906261811915)
# @JohnJHarwood   Obama support Iran &amp ; turn back on our allies in Saudi Arabia &amp ; Israel . What a weak leader &amp ; Foreign policy amateur .
#
# (0.99999999999999967, 0.99938832499374319)
# RT @Algemeiner : US backtrack on New Sanctions Emboldens Iran by send Message of American Weakness , Say Security Experts https://t.co/
#
# (0.99999999999999967, 0.99953873544231364)
# RT @4FreedominIran : .@sanabarghzahedi : Iran regime 's defeat in # Syria = beginning of end to # Iran regime # No2Rouhani # StopExecutionsIran ht
#
# (0.99999999999999967, 0.99942147114058155)
# Futures Movers : Oil end lower as Iran - Saudi Arabia tensions cloud outlook https://t.co/tJUL5nIGrg # trade # shares # forex
#
# (0.99999999999999967, 0.99942087590630091)
# RT @ImranKhanPTI : As tensions grow between Saudi Arabia &amp ; Iran , Pak must play a proactive role in resolve these tensions between the 2 Mu
#
# (0.99999999999999967, 0.99942087590630091)
# RT @ImranKhanPTI : As tensions grow between Saudi Arabia &amp ; Iran , Pak must play a proactive role in resolve these tensions between the 2 Mu
#
# (0.99999999999999967, 0.99953830254692932)
# RT @Mojahedineng : # Iran # News No . 2 House Dem : disappointed in Iran sanctions delay https://t.co/p5vaDXyVcb https://t.co/utLBRR5dhC
#
# (0.99999999999999967, 0.99961941183948189)
# RT @iran_policy : Saleh Hamid : Executions have soar in # Iran under Rouhani who claim to be moderate # No2Rouhani # StopExecutionsIran https
#
# (0.99999999999999967, 0.99933164598444491)
# RT @4FreedominIran : # Iran double Down on Strait of Hormuz Confrontation with Denials , Internal Orders https://t.co/iolFE4bgmh https://t.co
#
# (0.99999999999999967, 0.99938832499374319)
# RT @carlbildt : Distinctly bad move by Saudi Arabia to break diplomatic relations with Iran . will increase tension in the region . https://t .
#
# (0.99999999999999967, 0.99943496128591269)
# RT @4FreedominIran : Saleh Hamid : # Iran regime be fraught with internal struggle especially since Khamenei have cancer . This row benefit # Sy
#
# (0.99999999999999967, 0.99905123470367618)
# RT @4FreedominIran : Ahmad Ramazan : # Iran 's regime be anti - Arab and inhuman . # No2Rouhani # StopExecutionsIran https://t.co/QJEHoq3SyJ
#
# (0.99999999999999967, 0.99935431924312357)
# RT @Slate : Iran and Saudi Arabia 's escalating conflict be great news for ISIS https://t.co/bZwKvZl3eE https://t.co/w5suSk3C08
#
# (0.99999999999999967, 0.99927921183599588)
# RT @Mojahedineng : # Iran # News Rep. Lee Zeldin : For # Syria and Libya , there be no US plan at all https://t.co/q1cO8uDN5i https://t.co/Et2R4l
#
# (0.99999999999999967, 0.99961941183948189)
# RT @iran_policy : Saleh Hamid , law and political activist : Many ppl of # Iran live under poverty line . Drugs , unemployment , corruption be ra
#
# (0.99999999999999967, 0.99961941183948189)
# List of women execute under Rouhani regime ! https://t.co/vMLjs4g6Es   # humanRights # No2Rouhani # Iran # IranTalks https://t.co/x12y7rlfHO
#
# (0.99999999999999967, 0.99930982207740759)
# # News # Sudan&amp ; # Bahrain cut diplomatic ties w # Iran https://t.co/ghh6XBVZpQ # humanrights # StopExecutionsIran # Paris https://t.co/qBSRsj4p25
#
# (0.99999999999999967, 0.99922886548833834)
# RT @Donyayeazad : # Iran regime fear repeat of 2009 popular uprisings ahead of decisive https://t.co/wt0WTDd3Yv # stopexecutioniran https://
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Saleh Hamid : Right now many differences exist between # Iran regime + Russia in # Syria war . Iran feel it give casualties
#
# (0.99999999999999967, 0.99952098299037762)
# RT @iran_policy : Ahmad Ramazan , democratic Syrian opposition : # Iran regime be isolate at home . We will not allow it to spread terrorism in #
#
# (0.99999999999999967, 0.99942087590630091)
# RT @ImranKhanPTI : As tensions grow between Saudi Arabia &amp ; Iran , Pak must play a proactive role in resolve these tensions between the 2 Mu
#
# (0.99999999999999967, 0.99953830254692932)
# RT @redallover99 : IRGC Deputy Commander : Saudi Arabia No Big Deal for Iran
#
# (0.99999999999999967, 0.99942548344164106)
# RT @FreeBeacon : Saudi Arabia : Iran wait 12 Hours to send Security to Sieged Embassy https://t.co/q1KYydySfV via @Kredo0 https://t.co/FwJL
#
# (0.99999999999999967, 0.99922417088860904)
# RT @JavierBlas2 : # SaudiArabia FX reserves be down $ 100bn over last year -- but Riyadh still have plenty of ' petro - dollars ' # Iran # oil https
#
# (0.99999999999999967, 0.99920853782147179)
# RT @JeffreyGoldberg : From what I be read , it seem as if many people on both sides of the Saudi - Iran crisis agree on one thing : The Jews
#
# (0.99999999999999967, 0.99918288034468106)
# RT @iran_policy : Ahmad Ramazan : # Iran regime 's Al - Alam satellite TV broadcasts live from Damascus &amp ; have direct ties to Assad 's office . # Syr
#
# (0.99999999999999967, 0.9990354152331451)
# @forgefirst @BNN   Oh Andrew , you know exactly what Saudi and Iran will do regard oil supply , that ' the laugh of the year , and it ' Jan 4
#
# (0.99999999999999967, 0.99930982207740759)
# # Bahrain , # Sudan and # UAE follow Saudis in diplomatic action against Iran
#
# (0.99999999999999967, 0.99961941183948189)
# RT @Donyayeazad : List of women execute under Rouhani regime ! https://t.co/Gr3BjFB5HW   # stopexecutioniran # No2Rouhani # Iran # Syria https://
#
# (0.99999999999999967, 0.99916668359506233)
# RT @Mojahedineng : # Iran # News EUs foreign policy chief warn Iran on renew tension with Saudi Arabia https://t.co/ifzIVcWwOV https://t .
#
# (0.99999999999999967, 0.99938832499374319)
# RT @MicahZenko : Iran can retaliate by close its airspace to Emirates and Etihad ... logistics nightmare . https://t.co/nhJorXnXPZ https://t .
#
# (0.99999999999999967, 0.99952098299037762)
# RT @4FreedominIran : Ahmad Ramazan , democratic Syrian opposition : # Iran regime be isolate at home . We will not allow it to spread terrorism i
#
# (0.99999999999999967, 0.99938832499374319)
# RT @iran_policy : AhmadRamazan : # Iran regime be be defeat by # Syria revolutionaries . IRGC officers now feel they be be send to be k
#
# (0.99999999999999967, 0.99999999999999989)
# RT @cerenomri : " Literally every US ally in Mideast be on brink of hot war w/ Iran , so we 're go to release $ 100 billion to Iran this mont
#
# (0.99999999999999967, 0.99916668359506233)
# # Iran # News EUs foreign policy chief warn Iran on renew tension with Saudi Arabia https://t.co/cCbAr3MqsH   https://t.co/bVKAfxQZ1h
#
# (0.99999999999999967, 0.99942548344164106)
# RT @NasserSharif1 : .@WSJ :The Mullahs thank Mr. Obama # Iran # IranDeal https://t.co/uLAhj9sJ8c via WSJ
#
# (0.99999999999999967, 0.99913445213054752)
# RT @AlArabiya_Eng : OPINION : It ' surreal Iran ( execute 700 in first half of 2015 ) have the audacity to criticize # Saudi : @FaisalJAbbas http
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Ahmad Ramazan : # Iran regime no longer call the shots in # Syria war . It have be supercede by Russia . # No2Rouhani # StopEx
#
# (0.99999999999999967, 0.99943496128591269)
# Arab League to hold emergency talks on Iran - Saudi row # news https://t.co/xumXlcRAGF
#
# (0.99999999999999967, 0.99930945009030314)
# RT @AP : Saudi Arabia cut diplomatic ties with Iran amid tensions over Saudi Arabia 's execution of Shiite cleric : https://t.co/AyCrDNKokm
#
# (0.99999999999999967, 0.99905123470367618)
# .@fholande what if someone shake Hitler 's bloody hands ? do n't be that person . # Iran # Germany # Italy # Canada # UK https://t.co/rtDPT19IIX
#
# (0.99999999999999967, 0.9990377009524799)
# RT @XHNews : EU call on regional powers to act responsibly in Iran - Saudi Arabia tension https://t.co/gLhXXYdUbQ ( Reuters Pic ) https://t.co/
#
# (0.99999999999999967, 0.99961941183948189)
# RT @Maryam_Rajavi : kill under torture , death penalties &amp ; harass # Sunni prisoners in # Iran s prisons 4 protest against the regime
#
# (0.99999999999999967, 0.99906352601677006)
# RT @Mojahedineng : # Iran # News Nadler : US need to curtail Irans support for terrorism , condemn human rights https://t.co/X1tG0LEyCP https
#
# (0.99999999999999967, 0.99999999999999989)
# RT @4FreedominIran : Saleh Hamid : In reality # Iran IRGC Quds Force Gen. Qassem Soleimani be now out of action in # Syria war follow his in
#
# (0.99999999999999967, 0.99947401253784762)
# RT @Donyayeazad : # Iran regime plan 2 forcibly turn # Tehran church grounds into mosque . https://t.co/RSn0MWjiIC # stopexecutioniran https://
#
# (0.99999999999999967, 0.99905123470367618)
# .@fholande what if someone shake Hitler 's bloody hands ? do n't be that person . # Iran # Germany # Italy # Canada # UK https://t.co/tUcdR8Suei
#
# (0.99999999999999967, 0.99999999999999989)
# RT @4FreedominIran : Ahmad Ramazan : # Iran regime no longer call the shots in # Syria war . It have be supercede by Russia . # No2Rouhani # Sto
#
# (0.99999999999999967, 0.99930945009030314)
# GOBE ! Iran warn Nigeria to release Shiite leader El - Zakzaky - SEE https://t.co/TRshnC6sVU
#
# (0.99999999999999967, 0.99930945009030314)
# GOBE ! Iran warn Nigeria to release Shiite leader El - Zakzaky - SEE https://t.co/SlvcQtk3vE
#
# (0.99999999999999967, 0.99922417088860904)
# RT @alTusi313 : # Oman criticize # SaudiArabia for cut ties with # Iran
#
# (0.99999999999999967, 0.99922417088860904)
# RT @iran_policy : Saleh Hamid : sever of Arab states ' ties with # Iran regime benefit Iranian &amp ; # Syria opposition movements . # SaudiArabia
#
# (0.99999999999999967, 0.99912951498129021)
# ' We hope The Nigerian Govt will be Wise ' - Iran warn Nigeria Over Zakzaky 's Detention https://t.co/rMHaBGaLv0
#
# (0.99999999999999967, 0.99942147114058155)
# RT @Maryam_Rajavi : # UNSecurityCouncil must take action to put an end to abusing of # humanrights in # Iran &amp ; the terrible situation of prison
#
# (0.99999999999999967, 0.999251034760959)
# RT @4FreedominIran : Saleh Hamid : # Iran regime refuse to give info on IRGC Gen. Qassem Soleimani who be injure in # Syria . # No2Rouhani # St
#
# (0.99999999999999967, 0.99913445213054752)
# " # SaudiArabias destabilizing activities be vindication of nuclear deal it strike w/ # Iran in 2015 . " # IranDeal https://t.co/pSlCvSLLpO
#
# (0.99999999999999967, 0.99935431924312357)
# Saudi allies scale back ties with Iran as tensions soar - Hawaii News Now # news https://t.co/gvEQbVoVBy
#
# (0.99999999999999967, 0.99915297479655885)
# Any differences ? Iran Supreme Leader 's cartoon equate ISIS with Saudi Arabia @RT_com News https://t.co/14QHrBov1H https://t.co/h0K9ggemCF
#
# (0.99999999999999967, 0.99938044702084539)
# RT @iran_policy : Saleh Hamid : # Iran regime 's meddling in # Syria increase its internal bleeding . Rouhani fail to deliver on any of his pr
#
# (0.99999999999999967, 0.99942087590630091)
# RT @ImranKhanPTI : As tensions grow between Saudi Arabia &amp ; Iran , Pak must play a proactive role in resolve these tensions between the 2 Mu
#
# (0.99999999999999967, 0.99914102868996546)
# RT @Donyayeazad : # Iran : 1000s of victims of Padideh Shandiz Project protest plunder of their https://t.co/6NqDTXwC8Z # No2Rouhani https:/
#
# (0.99999999999999967, 0.99930982207740759)
# # News : # Bahrain sever diplomatic ties with The Ruling Regime`n # Iran ! https://t.co/2UZRMECqr6 # StopExecutionsIran https://t.co/GVWml3BdnM
#
# (0.99999999999999967, 0.99938832499374319)
# RT @iran_policy : AhmadRamazan : # Iran regime be be defeat by # Syria revolutionaries . IRGC officers now feel they be be send to be k
#
# (0.99999999999999967, 0.99961941183948189)
# RT @4FreedominIran : Saleh Hamid : Executions have soar in # Iran under Rouhani who claim to be moderate # No2Rouhani # StopExecutionsIran ht
#
# (0.99999999999999967, 0.99961941183948189)
# RT @Mojahedineng : # Iran # News # indian consulate under attack in Afghan city : official https://t.co/0U1b1EH3Xg https://t.co/l5YknIhCrA
#
# (0.99999999999999967, 0.99912951498129021)
# The Saudi - Iranian Crisis be Another Regional Powder Keg : Saudi Arabia and Iran , two " benevolent " pillar states of https://t.co/Wojwk6hnPo
#
# (0.99999999999999967, 0.99918741347518447)
# GOP op - ed : Obama " must maintain the sanctions on Iran " https://t.co/HRdvX6d9H7 https://t.co/YcbLbj4MD5
#
# (0.99999999999999967, 0.99942548344164106)
#   via https://t.co/942kPK1QD4
#
# (0.99999999999999967, 0.99923803058456784)
# The Latest : UN envoy for Syria heads to Saudi , Iran # GeneralNews https://t.co/ZsnDHMM42N
#
# (0.99999999999999967, 0.99938832499374319)
# could # Iran have bitter memories of all of its people kill by the chemical weapons we give Saddam Hussein ? https://t.co/k1XOmrpzKI
#
# (0.99999999999999967, 0.99951808569326417)
# RT @iran_policy : Saleh Hamid : Solution to regional crisis be for Arab states to support # Syria + # Iran opposition , especially as Tehran have
#
# (0.99999999999999967, 0.99961941183948189)
# RT @4FreedominIran : Saleh Hamid , law and political activist : Many ppl of # Iran live under poverty line . Drugs , unemployment , corruption be
#
# (0.99999999999999967, 0.99918288034468106)
# It ' time to say enough be enough to Iran ! If you wanna live in peace , you welcome to do so . Otherwise , bring it on . # kingsalman #
#
# (0.99999999999999967, 0.99961941183948189)
# # Iran # News # indian consulate under attack in Afghan city : official https://t.co/XGGflAI55u   https://t.co/PYzhOj6qGl
#
# (0.99999999999999967, 0.99935431924312357)
# [ # Reuters ] Exclusive : Saudi Arabia to halt flights , trade with Iran   # news Details : https://t.co/3Igr8bP88q
#
# (0.99999999999999967, 0.99942087590630091)
# RT @ImranKhanPTI : As tensions grow between Saudi Arabia &amp ; Iran , Pak must play a proactive role in resolve these tensions between the 2 Mu
#
# (0.99999999999999967, 0.9990377009524799)
# RT @XHNews : EU call on regional powers to act responsibly in Iran - Saudi Arabia tension https://t.co/gLhXXYdUbQ ( Reuters Pic ) https://t.co/
#
# (0.99999999999999967, 0.99918036848800407)
# RT @LyleKlich : Disarm America , import muslims and illegals , give them welfare , dismantle military and give Nukes to Iran ? Obama a muslim or
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Saleh Hamid : In reality # Iran IRGC Quds Force Gen. Qassem Soleimani be now out of action in # Syria war follow his injur
#
# (0.99999999999999967, 0.99942087590630091)
# be Hassan Rouhani a moderate ? know more about him ! https://t.co/Q9F1DkNBaK   # No2Rouhani # Iran # HumanRights # USA https://t.co/gARjnlBpZR 2
#
# (0.99999999999999967, 0.999251034760959)
# RT @iran_policy : Ahmad Ramazan : # Iran IRGC Gen. Qassem Soleimani say before we will send 100000 forces to Aleppo if need , but they now fac
#
# (0.99999999999999967, 0.99905123470367618)
# RT @iran_policy : Ahmad Ramazan : Reason for # Iran regime 's defeat in # Syria be that the land they be fight on be not theirs . https://t.c
#
# (0.99999999999999967, 0.99942548344164106)
# Iran open its first marathon to tourists - but women can n't compete | via @Telegraph https://t.co/Qw11McMR8A
#
# (0.99999999999999967, 0.99912951498129021)
# The islamic republic of Iran and human rights do n't go together . Public hangings be still common in the country . https://t.co/0QbAUN10tg
#
# (0.99999999999999967, 0.99930982207740759)
# RT @NickSotoudeh : # Bahrain follow Saudi Arabia and Severs Ties with # Iran https://t.co/fZV8AYMgWH
#
# (0.99999999999999967, 0.99999999999999989)
# RT @cerenomri : " Literally every US ally in Mideast be on brink of hot war w/ Iran , so we 're go to release $ 100 billion to Iran this mont
#
# (0.99999999999999967, 0.99938832499374319)
# RT @Mojahedineng : # Iran # News Mother kill by mortar fire in curfew - hit Turkish city https://t.co/Si4jMvwayE https://t.co/Q7l8A7LmF2
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Saleh Hamid : Right now many differences exist between # Iran regime + Russia in # Syria war . Iran feel it give casualties
#
# (0.99999999999999967, 0.99942548344164106)
# Saudi Arabia - Iran Rift complicate Bid to Calm Oil Markets   Energy Journal https://t.co/YN3f9BQyot via @WSJMoneyBeat # oilprices
#
# (0.99999999999999967, 0.99999999999999989)
# RT @4FreedominIran : Saleh Hamid : Right now many differences exist between # Iran regime + Russia in # Syria war . Iran feel it give casualti
#
# (0.99999999999999967, 0.99935431924312357)
# AP World : The Latest : Iran say it regret attacks on Saudi missions https://t.co/Xpcnl5o62J # news
#
# (0.99999999999999967, 0.99942548344164106)
# RT @amsafavi : maintain the sanctions on # Iran https://t.co/n73cSWEFq7 via @phillydotcom @voices_of_iran # irandeal @theirandeal @no2censorsh
#
# (0.99999999999999967, 0.99942548344164106)
# Saudi Clash With Iran , Worst Since 1980s , risk Deeper Conflict https://t.co/w2G7nbNUQy via @business
#
# (0.99999999999999967, 0.99918288034468106)
# RT @4FreedominIran : Ahmad Ramazan : # Iran regime 's Al - Alam satellite TV broadcasts live from Damascus &amp ; have direct ties to Assad 's office . #
#
# (0.99999999999999967, 0.99906352601677006)
# RT @QuintinaMarino : Theres just 1 way 2establish democracy&amp;freedom in # Iran . overthrow of Mullahs regime in its entirety # Paris # UK https :
#
# (0.99999999999999967, 0.99905123470367618)
# @mattduss and lead to growth in Sunni sectarianism . You may see Iran 's interests in the long - term as align with those of the US , but
#
# (0.99999999999999967, 0.99953830254692932)
# Obama Just get Iran To surrender Its Entire Nuclear Stockpile - Republicans have No Comment https://t.co/1NoVIs2aly
#
# (0.99999999999999967, 0.99920853782147179)
# RT @hahussain : Whoever think # Iran be defend Christians of the East , read this article and think again
#
# (0.99999999999999967, 0.99906352601677006)
# RT @iran_policy : Ahmad Ramazan : # Iran regime be face with major defeats in # Syria &amp ; will inevitably have to drink chalice of poison . https
#
# (0.99999999999999967, 0.99922417088860904)
# RT @mhashimazam : stay Calm ! # SaudiArabia # Iran # Altaf4InterFaithUnity https://t.co/FXPSjxRUzv
#
# (0.99999999999999967, 0.99955883680635205)
# RT @RudyHavenstein : BREAKING : Saudi Arabia have unfollowed Iran on Twitter and unfriended Iran on Facebook .
#
# (0.99999999999999967, 0.99952098299037762)
# RT @bjoernstritzel : After Iran storms embassy , KSA , Bahrain , UAE cut relationships , major Syrian rebel groups support the move . Good luck w
#
# (0.99999999999999967, 0.99948144235635394)
# If we saw what happen inYemen and Syria and the Iraq because of Iran 's interference in the affairs of those
#
# (0.99999999999999967, 0.99938832499374319)
# RT @4FreedominIran : AhmadRamazan : # Iran regime be be defeat by # Syria revolutionaries . IRGC officers now feel they be be send to b
#
# (0.99999999999999967, 0.99952098299037762)
# RT @bahareazady : # Iran # News Reporters Without Borders calls on Turkey to help protect Syrian reporters https://t.co/bYjYR21IoZ   https://t .
#
# (0.99999999999999967, 0.99938832499374319)
# RT @NCRI_Women_Comm : You should know that any deal you make with the # Iran regime will be pay by the lives of noble human beings https://t
#
# (0.99999999999999967, 0.99953873544231364)
# RT @iran_policy : Saleh Hamid : Reason for high casualty rate of Afghan forces in # Syria = # Iran regime just send them for money without tra
#
# (0.99999999999999967, 0.99912951498129021)
# RT @nntaleb : The fact that oil be not rally on Iran - KSA tension tell us some people be choke on inventory .
#
# (0.99999999999999967, 0.99930945009030314)
# Hhmmm . Iran claim to have ' warn Nigeria ' to release detain Shiite leader .... @afalli
#
# (0.99999999999999967, 0.99918036848800407)
# RT @weknowwhatsbest : Now that Pres Obama have work hard at arm Iran , today he will begin work hard at disarm you .
#
# (0.99999999999999967, 0.999251034760959)
# RT @iran_policy : Saleh Hamid : # Iran regime refuse to give info on IRGC Gen. Qassem Soleimani who be injure in # Syria . # No2Rouhani # StopE
#
# (0.99999999999999967, 0.99922886548833834)
# RT @4FreedominIran : Ahmad Ramazan : Reason for # Iran regime 's defeat in # Syria be that the land they be fight on be not theirs . https://
#
# (0.99999999999999967, 0.99923803058456784)
# UN chief calls on Iran , Saudi Arabia to avoid further exacerbate tensions after executions https://t.co/9Oe9rYkPrn
#
# (0.99999999999999967, 0.99917635217932887)
# RT @Google_Kugle20 : look like @HillaryClinton and Iran have similar strategies when an embassy be attack ... https://t.co/ACAueB4yVy
#
# (0.99999999999999967, 0.99918036848800407)
# RT @weknowwhatsbest : Now that Pres Obama have work hard at arm Iran , today he will begin work hard at disarm you .
#
# (0.99999999999999967, 0.99942087590630091)
# Reuters : # SaudiArabia 2 halt flights&amp ; trade with # Iran https://t.co/TdUmLuUY4X # humanrights # StopExecutionsIran https://t.co/vXbrlfZLjr
#
# (0.99999999999999967, 0.99905123470367618)
# RT @NCRI_Women_Comm : partner with # Iran ? Never forget regime 's # HumanRights Violations !
#
# (0.99999999999999967, 0.99905123470367618)
# .@fholande what if someone shake Hitler 's bloody hands ? do n't be that person . # Iran # Quebec # COP21Paris # Folketinget https://t.co/rtDPT19IIX
#
# (0.99999999999999967, 0.99953873544231364)
# RT @iran_policy : .@sanabarghzahedi : Iran regime 's defeat in # Syria = beginning of end to # Iran regime # No2Rouhani # StopExecutionsIran https
#
# (0.99999999999999967, 0.99905123470367618)
# RT @iran_policy : Ahmad Ramazan : # Iran regime recently saw it be lose grip of # Syria . With Russia 's entry , regime open 10 fronts in Syr
#
# (0.99999999999999967, 0.9990377009524799)
# RT @XHNews : EU call on regional powers to act responsibly in Iran - Saudi Arabia tension https://t.co/gLhXXYdUbQ ( Reuters Pic ) https://t.co/
#
# (0.99999999999999967, 0.99942548344164106)
# RT @amsafavi : maintain the sanctions on # Iran https://t.co/n73cSWEFq7 via @phillydotcom @voices_of_iran # irandeal @theirandeal @no2censorsh
#
# (0.99999999999999967, 0.99902357082838456)
# Iran - Saudi : explain it to me : As if the Middle East do n't already have enough tension , the https://t.co/lgqviVb1jZ
#
# (0.99999999999999967, 0.99938832499374319)
# RT @hotairblog : Iran deal backers embarrassed by Obama admins sanctionsblunder https://t.co/zGfe6vuUx0
#
# (0.99999999999999967, 0.99905123470367618)
# .@fholande what if someone shake Hitler 's bloody hands ? do n't be that person . # Iran # Quebec # COP21Paris # Folketinget https://t.co/tUcdR8Suei
#
# (0.99999999999999967, 0.99943496128591269)
# RT @iran_policy : Saleh Hamid : # Iran regime be fraught with internal struggle especially since Khamenei have cancer . This row benefits # Syria
#
# (0.99999999999999967, 0.99906352601677006)
# RT @NCRI_Women_Comm : cooperate with # Iran ? Never forget regime 's # HumanRights Violations ! FREE # AtenaFarghadani # StopExecutionsIran https
#
# (0.99999999999999967, 0.99952098299037762)
# RT @iran_policy : Ahmad Ramazan of Syrian oppo . : # Iran regime try to set up militias for its terrorist plots in # Syria . # No2Rouhani https :
#
# (0.99999999999999967, 0.99912951498129021)
# @andrewm54220189 @BreitbartLondon innocent Germans ? The same that support Iran ?
#
# (0.99999999999999967, 0.99922417088860904)
# RT @RT_com : # SaudiArabia cut all commercial ties , flights to # Iran https://t.co/y13OgNsH61 https://t.co/5OqySgbHSK
#
# (0.99999999999999967, 0.99943496128591269)
# RT @Donyayeazad : # Iran : 16 prisoners on the row of death penalty in GoharDasht prison ! # humanrights # StopExecutionsIran # No2Rouhani https:/
#
# (0.99999999999999967, 0.99961941183948189)
# RT @iran_policy : Saleh Hamid : Executions have soar in # Iran under Rouhani who claim to be moderate # No2Rouhani # StopExecutionsIran https
#
# (0.99999999999999967, 0.99923803058456784)
# # UN push # Syria , # Yemen peace amid ' worry ' # Saudi break with # Iran
#
# (0.99999999999999967, 0.99935431924312357)
# RT @iran_policy : .@sanabarghzahedi : State news agency IRNA admit that 400 of # Iran regime 's forces have be kill in # Syria https://t.co
#
# (0.99999999999999967, 0.99952098299037762)
# RT @jabbarianmina1 : # Iran # News Reporters Without Borders calls on Turkey to help protect Syrian reporters https://t.co/qRI6qIFp7a    https :
#
# (0.99999999999999967, 0.99922417088860904)
# RT @RT_com : # Iran Supreme Leader 's cartoon equate # ISIS with # SaudiArabia after # executions https://t.co/RaqDNTKUBd https://t.co/0UBFB7X8hY
#
# (0.99999999999999967, 0.99917635217932887)
# RT @Dr_Rafizadeh : # Iran attack the Egyptian embassy first , then the American , Denmark , British , and now the # Saudi embassy . be there a tr
#
# (0.99999999999999967, 0.99921183420743986)
# .@fholande Rouhani 's record ? 3 executions per day ! do n't be his partner in crime ! # Iran # No2Rouhani # Paris # UK https://t.co/tBWVrYIUym 1
#
# (0.99999999999999967, 0.99951808569326417)
# RT @4FreedominIran : Saleh Hamid : Solution to regional crisis be for Arab states to support # Syria + # Iran opposition , especially as Tehran
#
# (0.99999999999999967, 0.99924269434172608)
# UN Chief call Saudi Break In Ties With Iran ' Deeply Worrying '
#
# (0.99999999999999967, 0.99961941183948189)
# RT @iran_policy : Saleh Hamid , law and political activist : Many ppl of # Iran live under poverty line . Drugs , unemployment , corruption be ra
#
# (0.99999999999999967, 0.99921183420743986)
# be Hassan Rouhani a moderate ? know more about him ! https://t.co/3JiOcYADR1   # No2Rouhani # Iran # HumanRights # USA https://t.co/0AP3hOLKBw
#
# (0.99999999999999967, 0.99961941183948189)
# RT @iran_policy : Saleh Hamid : Executions have soar in # Iran under Rouhani who claim to be moderate # No2Rouhani # StopExecutionsIran https
#
# (0.99999999999999967, 0.99953873544231364)
# RT @iran_policy : Ahmad Ramazan of # Syria 's democratic opposition : # Iran regime 's official say for us control Syrian airport = controlin
#
# (0.99999999999999967, 0.999251034760959)
# RT @4FreedominIran : Ahmad Ramazan : # Iran IRGC Gen. Qassem Soleimani say before we will send 100000 forces to Aleppo if need , but they now
#
# (0.99999999999999967, 0.99930982207740759)
# RT @Mojahedineng : # Iran # News The Latest : # Bahrain sever diplomatic ties with Iran https://t.co/zJhqcVLclh https://t.co/ebDRhydGWH
#
# (0.99999999999999967, 0.99943496128591269)
# RT @Iran : # SaudiArabia recruit # Sunni allies in row with # Iran
#
# (0.99999999999999967, 0.99947401253784762)
# RT @seyyedreza : Neighborhoods where # Iran 's 100,000 # Armenians live , mostly in Tehran and Esfahan , go all out for Jan 6 Christmas https://t
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Saleh Hamid : Right now many differences exist between # Iran regime + Russia in # Syria war . Iran feel it give casualties
#
# (0.99999999999999967, 0.99921183420743986)
# be Hassan Rouhani a moderate ? know more about him ! https://t.co/oSNcq6bIin   # No2Rouhani # Iran # HumanRights # USA https://t.co/P1gyXyF3rE
#
# (0.99999999999999967, 0.99930982207740759)
# RT @Mojahedineng : # Iran # News # Bahrain be sever diplomatic ties with Iran https://t.co/zKX1P5KvXG https://t.co/5vdqCqa0fy
#
# (0.99999999999999967, 0.99943496128591269)
# Saudi Arabia - Iran row spread to other nations @CNN https://t.co/lTdZ7DoEaT
#
# (0.99999999999999967, 0.99901304573302852)
# RT @jihadwatchRS : Irans Supremo on Americans : Iran will punch them in the mouth https://t.co/91NDDuiSjm
#
# (0.99999999999999967, 0.99906352601677006)
# RT @iran_policy : Ahmad Ramazan : # Iran regime be face with major defeats in # Syria &amp ; will inevitably have to drink chalice of poison . https
#
# (0.99999999999999967, 0.99942548344164106)
# RT @paryvashmahmoo2 : maintain the sanctions on # Iran https://t.co/QQSYI4ulyo   via @phillydotcom @voices_of_iran # irandeal @theirandeal @no2
#
# (0.99999999999999967, 0.99951808569326417)
# RT @iran_policy : Ahmad Ramazan , # Syria 's democratic opposition : In 2012 Assad saw he could not defeat opposition forces , so # Iran regime +
#
# (0.99999999999999967, 0.99909439303618142)
# RT @Mojahedineng : # Iran # News Iran : victims of Padideh Shandiz Project in Mashhad be still demonstrate in https://t.co/9AoH6s3uPk https
#
# (0.99999999999999967, 0.99918288034468106)
# RT @iran_policy : Ahmad Ramazan : # Iran regime 's Al - Alam satellite TV broadcasts live from Damascus &amp ; have direct ties to Assad 's office . # Syr
#
# (0.99999999999999967, 0.99924269434172608)
# RT @mattduss : The US have nothing to gain from exacerbate sectarian tension in Mideast . In this regard , interests more align with Iran t
#
# (0.99999999999999967, 0.99913445213054752)
# RT @Reprieve : Iran , like Saudi , execute large numbers of people for non - violent offences - 500 hang on drugs charges in 2015 : https://t .
#
# (0.99999999999999967, 0.99922154075774028)
# RT @iran_policy : Ahmad Ramazan , head of media relations , # Syria 's democractic opposition : # Iran regime casualty rate in Syria be part of it
#
# (0.99999999999999967, 0.99953873544231364)
# RT @4FreedominIran : Saleh Hamid : Reason for high casualty rate of Afghan forces in # Syria = # Iran regime just send them for money without
#
# (0.99999999999999967, 0.99922417088860904)
# RT @RT_com : BREAKING : # SaudiArabia to cut off all air traffic , commercial ties with # Iran - foreign min https://t.co/OWjSxD2xJE https://t.c
#
# (0.99999999999999967, 0.99909439303618142)
# RT @Mojahedineng : # Iran # News Iran : Padideh Shandiz Project victims stage a protest rally in # tehran +#photos https://t.co/zJ4MiClMyW https
#
# (0.99999999999999967, 0.99919283992835661)
# @khamenei_ir The only beneficiaries of " DAESH " existence thus far be Iran 's regime ( along with Assad ) and Israel . I wonder why .. .... .... ! ?
#
# (0.99999999999999967, 0.99917672917733835)
# RT @tak31523 : 1,587 days # USMC # VET # AmirHekmati have be hold as a # Politicalprisoner in # Evin prison # Iran          # FreeAmirNow https://t
#
# (0.99999999999999967, 0.99921183420743986)
# .@fholande Rouhani 's record ? 3 executions per day ! do n't be his partner in crime ! # Iran # No2Rouhani # Paris # UK https://t.co/dXQqAD1IhF
#
# (0.99999999999999967, 0.99942548344164106)
# maintain the sanctions on # Iran ! https://t.co/O9wjnVNq1L via @phillydotcom by Pat Toomey&amp ; Tom Ridge # No2Rouhani https://t.co/Nxj7ZThK6N
#
# (0.99999999999999967, 0.99905123470367618)
# RT @4FreedominIran : Ahmad Ramazan : # Iran regime recently saw it be lose grip of # Syria . With Russia 's entry , regime open 10 fronts in
#
# (0.99999999999999967, 0.99938832499374319)
# RT @iran_policy : AhmadRamazan : # Iran regime be be defeat by # Syria revolutionaries . IRGC officers now feel they be be send to be k
#
# (0.99999999999999967, 0.99900645719903436)
# RT @Mojahedineng : # Iran # News Iranian Christians be force to give up church grounds for build mosque https://t.co/wM12eq5g4L https://t
#
# (0.99999999999999967, 0.99953873544231364)
# RT @4FreedominIran : .@sanabarghzahedi : Iran regime 's defeat in # Syria = beginning of end to # Iran regime # No2Rouhani # StopExecutionsIran ht
#
# (0.99999999999999967, 0.99921183420743986)
# .@fholande ask Rouhani about 2000 executions . do not shake hand with murderers # Iran # France # Paris # No2Rouhani https://t.co/Ja4BZW8vhW 1
#
# (0.99999999999999967, 0.99921183420743986)
# .@fholande Rouhani 's record ? 3 executions per day ! do n't be his partner in crime ! # Iran # No2Rouhani # Paris # UK https://t.co/lnjg0J4aLw
#
# (0.99999999999999967, 0.99905880620006793)
# Where be all the Pakis wen Iran execute Sunni leaders for speak against the state ?
#
# (0.99999999999999967, 0.99947401253784762)
# RT @seyyedreza : Neighborhoods where # Iran 's 100,000 # Armenians live , mostly in Tehran and Esfahan , go all out for Jan 6 Christmas https://t
#
# (0.99999999999999967, 0.99961941183948189)
# RT @jabbarianmina1 : List of # women execute under Rouhani regime ! https://t.co/JZhc7W6cdA # humanRights # No2Rouhani # Iran # IranTalks https:/
#
# (0.99999999999999967, 0.99953873544231364)
# RT @4FreedominIran : Ahmad Ramazan of # Syria 's democratic opposition : # Iran regime 's official say for us control Syrian airport = contro
#
# (0.99999999999999967, 0.99999999999999989)
#  # Jewishconspiracy
#
# (0.99999999999999967, 0.99906123487561183)
# Saudi Arabia be really bully Iran all cause Iran about to turn they taps on smh people can n't see its clear as day
#
# (0.99999999999999967, 0.99922886548833834)
# RT @azardaneshgu : Theres just 1 way 2establish democracy&amp;freedom in # Iran . overthrow of Mullahs regime in its entirety # Paris # UK https://
#
# (0.99999999999999967, 0.99915297479655885)
# RT @briangaar : We should definitely trust Saudi Arabia , a gangster regime that birth ISIS and bin Laden , over Iran
#
# (0.99999999999999967, 0.99953873544231364)
# RT @iran_policy : Saleh Hamid : Reason for high casualty rate of Afghan forces in # Syria = # Iran regime just send them for money without tra
#
# (0.99999999999999967, 0.99943496128591269)
# RT @4FreedominIran : Saleh Hamid : # Iran regime be fraught with internal struggle especially since Khamenei have cancer . This row benefit # Sy
#
# (0.99999999999999967, 0.99922886548833834)
# RT @Mojahedineng : # Iran # News Iran : 4 prisoners in Gohadasht Prison begin their second week of hunger https://t.co/8K0E97h1fd https://
#
# (0.99999999999999967, 0.99924269434172608)
# RT @4FreedominIran : Ahmad Ramazan , # Syria 's democratic opposition : In 2012 Assad saw he could not defeat opposition forces , so # Iran regime
#
# (0.99999999999999967, 0.99947401253784762)
# RT @MAZANDARA : RT.@FranTownsend:#Saudi Foreign Ministry say Embassy in # Tehran # Iran receive telephonic death . # maryamrajavi . # camplibert
#
# (0.99999999999999967, 0.99932876603034504)
# Maryam Rajavi Congress : Regime change in Iran necessary for counter Islamic fundamentalism - Newsbydiva 's Blog https://t.co/BcdueXtEdl
#
# (0.99999999999999967, 0.99999999999999989)
# RT @4FreedominIran : Saleh Hamid : In reality # Iran IRGC Quds Force Gen. Qassem Soleimani be now out of action in # Syria war follow his in
#
# (0.99999999999999967, 0.99961941183948189)
# List of # women execute under Rouhani regime ! https://t.co/x42BNoPElj # humanRights # No2Rouhani # Iran # IranTalks https://t.co/HV1exWekVz # ZDF
#
# (0.99999999999999967, 0.99905123470367618)
# RT @iran_policy : Ahmad Ramazan , # Syria 's democratic opposition : # Iran regime be now the symbol of terrorism around the world . # No2Rouhani #
#
# (0.99999999999999967, 0.99918036848800407)
# RT @KenGardner11 : Arab allies be break diplomatic relations with Iran . Obama 's response ? release $ 100 billion to Iran . The quintessenti
#
# (0.99999999999999967, 0.99947995217248198)
# RT @Reprieve : Execution of Iranian - American man " highlight the rise use of capital punishment in Iran " , write @SaeedKD : https://t.co/QM
#
# (0.99999999999999967, 0.99999999999999989)
# RT @wikileaks : The cold war between # Saudi Arabia and # Iran that ' tear apart the Middle East , explain https://t.co/vyoUIDT994
#
# (0.99999999999999967, 0.99905123470367618)
# RT @4FreedominIran : Ahmad Ramazan , # Syria 's democratic opposition : # Iran regime be now the symbol of terrorism around the world . # No2Rouhan
#
# (0.99999999999999967, 0.99905123470367618)
# RT @paryvashmahmoo2 : Ahmad Ramazan : # Iran 's regime be anti - Arab and inhuman . # No2Rouhani # StopExecutionsIran https://t.co/11B0VxP2jC
#
# (0.99999999999999967, 0.99913445213054752)
# AlArabiya_Eng : OPINION : It ' surreal Iran ( execute 700 in first half of 2015 ) have the audacity to criticize # Saud https://t.co/KE7OLLamCJ
#
# (0.99999999999999967, 0.99913445213054752)
# AlArabiya_Eng : OPINION : It ' surreal Iran ( execute 700 in first half of 2015 ) have the audacity to criticize # Saud https://t.co/kuqVQTl2Np
#
# (0.99999999999999967, 0.99942548344164106)
# RT @amsafavi : maintain the sanctions on # Iran https://t.co/n73cSWEFq7 via @phillydotcom @voices_of_iran # irandeal @theirandeal @no2censorsh
#
# (0.99999999999999967, 0.99905123470367618)
# # News Sheikh 's execution all about settle scores with Iran : ... state - sponsor persecution for over a ... https://t.co/ACupBpNlAf # HRW
#
# (0.99999999999999967, 0.99942087590630091)
# RT @ImranKhanPTI : As tensions grow between Saudi Arabia &amp ; Iran , Pak must play a proactive role in resolve these tensions between the 2 Mu
#
# (0.99999999999999967, 0.9990377009524799)
# Pakistan call for peaceful resolution to # S. Arabia , # Iran tensions https://t.co/zBKlKi01ot
#
# (0.99999999999999967, 0.999251034760959)
# RT @4FreedominIran : Saleh Hamid : # Iran regime refuse to give info on IRGC Gen. Qassem Soleimani who be injure in # Syria . # No2Rouhani # St
#
# (0.99999999999999967, 0.99918741347518447)
# .@POTUS should keep # Iran sanctions in place . I highlight some of Iran 's most egregious offenses here : https://t.co/7IQZ0FoQKe
#
# (0.99999999999999967, 0.99905123470367618)
# # News Sheikh 's execution all about settle scores with Iran : ... state - sponsor persecution for over a ... https://t.co/NJa6Luzx6a # HRW
#
# (0.99999999999999967, 0.99919283992835661)
# newStream : Middle East on the brink : Saudi - Iran crisis at boling point as Hezbollah - Israel hostilities erupt ... https://t.co/NUmPU9lVJo
#
# (0.99999999999999967, 0.99914102868996546)
# RT @MaajidNawaz : My @thedailybeast column on the Saudi executions &amp ; their theocratic rivalry with Iran , now with an additional update https
#
# (0.99999999999999967, 0.99922417088860904)
# RT @iran_policy : Saleh Hamid : sever of Arab states ' ties with # Iran regime benefit Iranian &amp ; # Syria opposition movements . # SaudiArabia
#
# (0.99999999999999967, 0.99947401253784762)
# RT @BehzadMoezi : Saudi cuts ties with Iran , expel Tehran envoys https://t.co/7doBm1xxQH
#
# (0.99999999999999967, 0.99901304573302852)
# RT @Mojahedineng : # Iran # News Arab League condemn attacks on Saudi Embassy , Consulate in Iran https://t.co/P4Wbja2s6x https://t.co/A0eBrbk
#
# (0.99999999999999967, 0.99942147114058155)
# RT @iran_policy : Ahmad Ramazan : # Iran regime fail in its ploys . Its terrorist plots abroad be mean to help end its domestic quagmire . #
#
# (0.99999999999999967, 0.99999999999999989)
# The Sunni - Shia conflict be n't about religion . It ' about the Iran - Saudi cold war RT https://t.co/hsgEYpdxvL
#
# (0.99999999999999967, 0.99912951498129021)
# RT @AJEnglish : Opinion : The escalate rivalries between Iran and Saudi Arabia have nothing to do with the Sunni - Shia divide https://t.co/j
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Saleh Hamid : In reality # Iran IRGC Quds Force Gen. Qassem Soleimani be now out of action in # Syria war follow his injur
#
# (0.99999999999999967, 0.99921183420743986)
# @fholande Rouhani wo n't drink wine , but will kill 3 people every day ! # Iran https://t.co/KdCgaUBeBF @hadeelOueiss @msadidoost @bahareazady
#
# (0.99999999999999967, 0.99953873544231364)
# RT @4FreedominIran : .@sanabarghzahedi : Iran regime 's defeat in # Syria = beginning of end to # Iran regime # No2Rouhani # StopExecutionsIran ht
#
# (0.99999999999999967, 0.99942147114058155)
# RT @4FreedominIran : Ahmad Ramazan : # Iran regime fail in its ploys . Its terrorist plots abroad be mean to help end its domestic quagmire
#
# (0.99999999999999967, 0.99901304573302852)
# RT @TomFitton : " If spy on Congress to undermine legislative efforts to defeat the Iran nuclear deal be not impeachable , what is?"https:/
#
# (0.99999999999999967, 0.99923803058456784)
# RT @meshaluk : Refusal of UN resolutions , disrespect diplomatic covenant &amp ; sovereignty violation R common things between Iran , ISIS , Hezb
#
# (0.99999999999999967, 0.99930982207740759)
# RT @VOANews : Middle East escalation : # Bahrain follow Saudi Arabia in sever ties with # Iran - https://t.co/kX9Zlp5tR4 https://t.co/85gpf
#
# (0.99999999999999967, 0.99902357082838456)
# Iran - Saudi : explain it to me : As if the Middle East do n't already have enough tension , the caustic feud https://t.co/Ak4sFCu1vq # cnn
#
# (0.99999999999999967, 0.99921183420743986)
# @fholande Rouhani wo n't drink wine , but will kill 3 people every day ! # Iran https://t.co/tJScMB1rQv @hadeelOueiss @msadidoost @bahareazady
#
# (0.99999999999999967, 0.99901304573302852)
# RT @CRG_CRM : US threaten New Sanctions on Iran https://t.co/jjsgLpkuUC https://t.co/SCiehJHOo2
#
# (0.99999999999999967, 0.99951808569326417)
# RT @4FreedominIran : Saleh Hamid : Solution to regional crisis be for Arab states to support # Syria + # Iran opposition , especially as Tehran
#
# (0.99999999999999967, 0.99938832499374319)
# RT @ZaidZamanHamid : Our serious and candid analysis of foreign policy be run by Hindu Zionists &amp ; the crises of Iran Saudi conflict ..
#
# (0.99999999999999967, 0.99961941183948189)
# RT @4FreedominIran : Saleh Hamid : Executions have soar in # Iran under Rouhani who claim to be moderate # No2Rouhani # StopExecutionsIran ht
#
# (0.99999999999999967, 0.99942548344164106)
# Iran - Saudi : explain it to me https://t.co/woKURQjLET via [ CNN Int . ]
#
# (0.99999999999999967, 0.999251034760959)
# RT @iran_policy : Saleh Hamid : # Iran regime refuse to give info on IRGC Gen. Qassem Soleimani who be injure in # Syria . # No2Rouhani # StopE
#
# (0.99999999999999967, 0.99952098299037762)
# RT @4FreedominIran : Ahmad Ramazan of Syrian oppo . : # Iran regime try to set up militias for its terrorist plots in # Syria . # No2Rouhani htt
#
# (0.99999999999999967, 0.99942548344164106)
# INN Iran be out ! https://t.co/mBnnjTFR15 Stories via @BBCKasraNaji @IranPrimer
#
# (0.99999999999999967, 0.99930982207740759)
# Saudi Arabia 's allies Bahrain , Sudan and UAE act against Iran https://t.co/FJx5jujQaa
#
# (0.99999999999999967, 0.99938832499374319)
# The hilarious thing about Saudi - Iran be Sudan lead by Bashir be cut diplomatic ties with Iran .
#
# (0.99999999999999967, 0.99901304573302852)
# RT @meshaluk : Iran will pay an exorbitant price on political &amp ; economical levels for dare to desecrate the Saudi embassy ! #
#
# (0.99999999999999967, 0.99961941183948189)
# RT @4FreedominIran : Saleh Hamid , law and political activist : Many ppl of # Iran live under poverty line . Drugs , unemployment , corruption be
#
# (0.99999999999999967, 0.99943496128591269)
# RT @4FreedominIran : Saleh Hamid : # Iran regime be fraught with internal struggle especially since Khamenei have cancer . This row benefit # Sy
#
# (0.99999999999999967, 0.99922417088860904)
# Hard to support anything # Iran do but they have every right to let world know that # SaudiArabia greater threat to world peace than they be
#
# (0.99999999999999967, 0.99942548344164106)
# Who  side with Saudi Arabia in rift with Iran ? | PBS NewsHour https://t.co/82Y0J6sjtx via @NewsHour
#
# (0.99999999999999967, 0.99938832499374319)
# RT @Mojahedineng : # Iran # News Saudi embassy in # tehran be attack and damage by Iranian regime mobs https://t.co/qTniZnBEw2 https://t.co
#
# (0.99999999999999967, 0.99923329446108577)
# ...
# RT @iran_policy : Saleh Hamid : In reality # Iran IRGC Quds Force Gen. Qassem Soleimani be now out of action in # Syria war follow his injur
#
# (0.99999999999999967, 0.99916668359506233)
# # Saudi foreign minister : # Iran have be defeat in # Yemen &amp ; will not be able to save # Assad regime in # Syria https://t.co/34ywbiOO9h
#
# (0.99999999999999967, 0.99932876603034504)
# RT @4FreedominIran : .@sanabarghzahedi : give # Iran regime 's casualties in # Syria , hegemony be now with Russia &amp ; this speak of change of ba
#
# (0.99999999999999967, 0.99919283992835661)
# RT @ketultheking786 : Russia do n't talk to Turki , Israel do n't talk to Iran , US do n't talk to Syria ; why do Modi insist on talks ? ?
#
# (0.99999999999999967, 0.99942548344164106)
# " U.S. say Expects Syria Meetings to go Forward Despite Saudi - Iran Tensions " by REUTERS via NYT https://t.co/MHQHCGVInN
#
# (0.99999999999999967, 0.99922417088860904)
# RT @iran_policy : Saleh Hamid : sever of Arab states ' ties with # Iran regime benefit Iranian &amp ; # Syria opposition movements . # SaudiArabia
#
# (0.99999999999999967, 0.99923803058456784)
# # UN envoy to Libya , Martin Kobler be evict from Libya https://t.co/X6X4kILHEw https://t.co/pHRAA5W3Jm # MTP # FNS # Iran @FoxNews # News
#
# (0.99999999999999967, 0.99923803058456784)
# # UN envoy to Libya , Martin Kobler be evict from Libya https://t.co/7isZ4KFvJy # MTP # FNS # Iran @FoxNews # News
#
# (0.99999999999999967, 0.99927921183599588)
# # Iran # News Rep. Lee Zeldin : For # Syria&amp ; Libya , there be no US plan at all ! https://t.co/u2JJ03UQ52 # No2Rouhani https://t.co/VCe3ne4Ird # ZDF
#
# (0.99999999999999967, 0.99922417088860904)
# RT @iran_policy : Saleh Hamid : sever of Arab states ' ties with # Iran regime benefit Iranian &amp ; # Syria opposition movements . # SaudiArabia
#
# (0.99999999999999967, 0.9990354152331451)
# # Iran as well as # Saudiarabia should stop fund terrorism in Pakistan thn we should play any role 4 ny unity # PakistanForIslamicUnity
#
# (0.99999999999999967, 0.99948144235635394)
# # Iraq # Iran # SaudiArabia
#
# (0.99999999999999967, 0.99947401253784762)
# Tehran must " act like a normal country " before Saudi restore diplomatic relations , say Saudi FM https://t.co/vHZTTIDMSR # SaudiArabia # Iran
#
# (0.99999999999999967, 0.99913445213054752)
# RT @NIACouncil : " # SaudiArabias destabilize activities be vindication of nuclear deal it strike w/ # Iran in 2015 . " # IranDeal https://t.c
#
# (0.99999999999999967, 0.99938832499374319)
# @saudgo @Reuters   yes ! the saudis ( back by Israel ) just want to show their " power " after the Iran nuclear deal .
#
# (0.99999999999999967, 0.99940186323280644)
# MT @TeriGRight : ' A Nuclear Iran present existential threat to Israel . ' # CruzCrewIsrael https://t.co/A8WujLmMFB # CruzCrew # PJNET
#
# (0.99999999999999967, 0.99948144235635394)
# Saudi v. Iran v. Bahrain v. Israel v. Syria v. Iraq v. Sunnis v. Shiites v. Putin v. Obama . Where do it stop ?
#
# (0.99999999999999967, 0.99949007129945444)
# RT @DavidKenner : So Israel and Hezbollah be fight , Yemen and Syria be on fire , Iran and Saudi be escalate , ISIS have new executioner
#
# (0.99999999999999967, 0.99947401253784762)
# RT @jabbarianmina1 : # Saudi cuts ties with # Iran , expel Tehran envoys https://t.co/nwyTaPlrXs # Middleeast # StopIranTerror # Humanrights # Syr
#
# (0.99999999999999967, 0.99947401253784762)
# Iran regime plan to forcibly turn Tehran church grounds into mosque https://t.co/yTpm9sbOt2 # No2Rouhani # Iran https://t.co/q4B8KzS3pd
#
# (0.99999999999999967, 0.99952098299037762)
# RT @iran_policy : Ahmad Ramazan , democratic Syrian opposition : # Iran regime be isolate at home . We will not allow it to spread terrorism in #
#
# (0.99999999999999967, 0.99938832499374319)
# # Bahrain slam hypocritical comments by # Iran regime . https://t.co/2R6fI1irY5 # MiddleEast # MTP # FNS # Obama # News
#
# (0.99999999999999967, 0.99947995217248198)
# RT @wikileaks : How False Stories of # Iran Arming the # Houthis be use to justify War in # Yemen https://t.co/Yfgmy57OxZ https://t.co/R3UIs
#
# (0.99999999999999967, 0.99951808569326417)
# RT @iran_policy : Ahmad Ramazan , # Syria 's democratic opposition : In 2012 Assad saw he could not defeat opposition forces , so # Iran regime +
#
# (0.99999999999999967, 0.99942147114058155)
# RT @4FreedominIran : Ahmad Ramazan : # Iran regime fail in its ploys . Its terrorist plots abroad be mean to help end its domestic quagmire
#
# (0.99999999999999967, 0.999251034760959)
# RT @iran_policy : .@sanabarghzahedi : Our info say Putin - Khamenei agree in meeting that # Iran IRGC send in ground forces full force &amp ; Russ
#
# (0.99999999999999967, 0.99901304573302852)
# @je_suis_liberte @sz_zaidi Oh that will come . Iran will blame America . Saudis will blame America , zionists for divide Muslims . Hang on .
#
# (0.99999999999999967, 0.99906123487561183)
# RT @Hassan__Hadi : Theres just 1 way 2establish democracy&amp;freedom in # Iran . overthrow of Mullahs regime in its entirety # Paris # AFP https:/
#
# (0.99999999999999967, 0.99922775216497217)
# Top # USA House Democrat disappoint at # Iran sanctions delay . https://t.co/NDSWezOBgk # News # MTP # FNS # Obama
#
# (0.99999999999999967, 0.99999999999999989)
# RT @wikileaks : The cold war between # Saudi Arabia and # Iran that ' tear apart the Middle East , explain https://t.co/vyoUIDT994
#
# (0.99999999999999967, 0.99901304573302852)
# RT @IranNewsUpdate1 : # Iran double Down on Strait of Hormuz Confrontation with Denials , Internal Orders https://t.co/1Lq0Txo6jx https://t.c
#
# (0.99999999999999967, 0.99955661350328273)
# # Syria : Over 55,000 people include 2,500 children kill in 2015 https://t.co/qlsgYQxbLF # Iran # MTP # FNS # News
#
# (0.99999999999999967, 0.99922837538301235)
# RT @aliamir1342 : Rouhani be absolutely responsible for crime against humanity in # CampLiberty # Iran # HumanRights # Europe # US # UK https://t .
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : .@sanabarghzahedi : ... so # Iran IRGC Quds Force commander Qassem Soleimani go to Moscow to seek help in # Syria war https
#
# (0.99999999999999967, 0.99961941183948189)
# RT @Maryam_Rajavi : kill under torture , death penalties &amp ; harass # Sunni prisoners in # Iran s prisons 4 protest against the regime
#
# (0.99999999999999967, 0.99922775216497217)
# Top # USA House Democrat disappoint at # Iran sanctions delay . https://t.co/T58mhyf54L # News # MTP # FNS # Obama
#
# (0.99999999999999967, 0.99999999999999989)
# RT @iran_policy : Ahmad Ramazan : # Iran regime no longer call the shots in # Syria war . It have be supercede by Russia . # No2Rouhani # StopEx
#
# (0.99999999999999967, 0.99923803058456784)
# UN chief call Saudi break in ties with Iran " deeply worry " https://t.co/CJTPAd5QFf https://t.co/ekKkfLxy2D https://t.co/Trwu2uBn1H #
#
# (0.99999999999999967, 0.99942548344164106)
# NigeriaNewsdesk : Oil prices rise after Saudi Arabia cut ties with Iran https://t.co/558yLiy87t via todayng https://t.co/iTKHyeCzhL
#
# (0.99999999999999967, 0.99947995217248198)
# @shokufeyesib How False Stories of # Iran Arming the Houthis be use to justify War in # Yemen https://t.co/jPt8jvU2Bt
#
# (0.99999999999999967, 0.99955661350328273)
# # Syria : Over 55,000 people include 2,500 children kill in 2015 https://t.co/l6CAUniyRH # Iran # MTP # FNS # News
#
# (0.99999999999999967, 0.99942087590630091)
# RT @ImranKhanPTI : As tensions grow between Saudi Arabia &amp ; Iran , Pak must play a proactive role in resolve these tensions between the 2 Mu
#
# (0.99999999999999967, 0.99922775216497217)
# Top # USA House Democrat disappoint at # Iran sanctions delay . https://t.co/Kuk43MnZSg # News # MTP # FNS # Obama
#
# (0.99999999999999967, 0.99953873544231364)
# RT @iran_policy : Ahmad Ramazan of # Syria 's democratic opposition : # Iran regime 's official say for us control Syrian airport = controlin
#
# (0.99999999999999967, 0.99938832499374319)
# RT @iran_policy : .@sanabarghzahedi : Its military casualties in # Syria &amp ; advances by opposition forces prompt # Iran regime to seek Russian
#
# (0.99999999999999967, 0.99923803058456784)
# RT @gmanews : UN chief call Saudi break in ties with Iran " deeply worry " https://t.co/C3AgTtqNrJ https://t.co/MpemJIxEUj
#
# (0.99999999999999967, 0.99919860491288759)
# RT @RBMORD : BBC News - Iran - Saudi crisis ' most dangerous for decades ' https://t.co/lxAx9hBNsf    # ThisTooShallPass
#
# (0.99999999999999967, 0.99906938336674544)
# # Iran regime hang two prisoners https://t.co/wmoXj3jBUh # No2Rouhani # IranFreedom # StopExecutionsIran # HumanRights https://t.co/jyt1NPAtuk
#
# (0.99999999999999967, 0.99999999999999989)
# RT @wikileaks : The cold war between # Saudi Arabia and # Iran that ' tear apart the Middle East , explain https://t.co/vyoUIDT994
#
# (0.99999999999999967, 0.99942548344164106)
# Saudi Arabia Just announce It plan On Severing Ties With Iran after a Tumultuous Weekend https://t.co/ERj1bScAn5 via @ijdotcom
#
# (0.99999999999999967, 0.99901304573302852)
# Saudi Arabia have learn how to deal with Iran , they wo n't ! catch on yet ?
#
# (0.99999999999999967, 0.99902357082838456)
# RT @DavidKWilliams : As Saudi Arabia sever ties with Iran , questions loom in volatile region be this " the Archduke Ferdinand " for WWIII ? ht
#
# (0.99999999999999967, 0.99949007129945444)
# RT @FranTownsend : White House delays impose new sanctions on # Iran for missile program         https://t.co/Y5lYmIbEdP
#
# (0.99999999999999967, 0.99947401253784762)
# Nearly 20 days of chock air pollution in # Tehran leave millions in distress https://t.co/QmEhcIDpm7 # Iran # MTP
#
# (0.99999999999999967, 0.99952098299037762)
# RT @4FreedominIran : Ahmad Ramazan of Syrian oppo . : # Iran regime try to set up militias for its terrorist plots in # Syria . # No2Rouhani htt
#
# (0.99999999999999967, 0.99938044702084539)
# RT @iran_policy : Saleh Hamid : # Iran regime 's meddling in # Syria increase its internal bleeding . Rouhani fail to deliver on any of his pr
#
# (0.99999999999999967, 0.99948144235635394)
# # SunniVShia # Saudi # Iran # Iraq # ThreatToEscalate # SHTF https://t.co/HXNIuELsta
#
# (0.99999999999999967, 0.99914102868996546)
# Thousands of people in Shandiz protest the plunder of their property .. https://t.co/1B8AYAtZFe   # No2Rouhani # Iran https://t.co/he2Y1accW6
#
# (0.99999999999999967, 0.99942548344164106)
# Khamenei say US faces ' punch in mouth ' in upcoming Iran elections https://t.co/TGfFxpCLUu via @GlobalPost
#
# (0.99999999999999967, 0.99953873544231364)
# RT @4FreedominIran : Ahmad Ramazan of # Syria 's democratic opposition : # Iran regime 's official say for us control Syrian airport = contro
#
# (0.99999999999999967, 0.99915297479655885)
# # Trump # ISIS # Iran # TPP
#
# (0.99999999999999967, 0.99906123487561183)
# RT @HannahAllam : Q do Iran do its best to protect Saudi embassy ? State:It ' just too soon to know . Reporter : I be look at YouTube see
#
# (0.99999999999999967, 0.99942548344164106)
# look for oil prices to spike if hostility between Iran and Saudi Arabia get worse https://t.co/ywZEomndwM via @qz
#
# (0.99999999999999967, 0.99922154075774028)
# RT @4FreedominIran : Ahmad Ramazan , head of media relations , # Syria 's democractic opposition : # Iran regime casualty rate in Syria be part of
#
# (0.99999999999999967, 0.99951808569326417)
# RT @iran_policy : Saleh Hamid : Solution to regional crisis be for Arab states to support # Syria + # Iran opposition , especially as Tehran have
#
# (0.99999999999999967, 0.99943496128591269)
# RT @ReutersUK : Saudi Arabia recruit Sunni allies in row with Iran https://t.co/LcyOUvu2Gm https://t.co/zXTxz6NVHZ
#
# (0.99999999999999967, 0.99938832499374319)
# # Bahrain slam hypocritical comments by # Iran regime . https://t.co/5WdJjftMdV # MiddleEast # MTP # FNS # Obama # News
#
# (0.99999999999999967, 0.99905123470367618)
# Sudanese Ambassador : Sudan 's Announcement on Severing Ties with # Iran Came as Solidarity with Kingdom . # SPAGOV
#
# (0.99999999999999967, 0.99947995217248198)
# RT @AlfaPedia : Iran &amp ; Saudia have a history to make religion suffer &amp ; use it for political interests . But our Pakistani Londay be unable t
#
# (0.99999999999999967, 0.99905123470367618)
# RT @BenjaminNorton : US urge " calm " after Saudi Arabia cut Iran ties , but say nothing about Saudi monarchy 's mass beheadings of 47
#
# (0.99999999999999967, 0.99999999999999989)
# AIPAC threaten Obama with war &amp ; want to destroy Iran . https://t.co/X31MWxqaKM
#
# (0.99999999999999967, 0.99905123470367618)
# RT @4FreedominIran : Ahmad Ramazan : # Iran regime recently saw it be lose grip of # Syria . With Russia 's entry , regime open 10 fronts in
#
# (0.99999999999999967, 0.999251034760959)
# RT @iran_policy : .@sanabarghzahedi : Our info say Putin - Khamenei agree in meeting that # Iran IRGC send in ground forces full force &amp ; Russ
#
# (0.99999999999999967, 0.99961941183948189)
# List of women execute under Rouhani regime ! https://t.co/5qUfsU05jD # humanRights # No2Rouhani # Iran # IranTalks https://t.co/fZrK2tiAYg
#
# (0.99999999999999967, 0.99919283992835661)
# RT @RossMorley : What a great # Greenwald piece - enjoy ! https://t.co/YuCIe47kyN # Privacy # espionage # NSA # Congress # Israel # Iran # Obama # Hoe
#
# (0.99999999999999967, 0.99938832499374319)
# RT @MicahZenko : Iran can retaliate by close its airspace to Emirates and Etihad ... logistics nightmare . https://t.co/nhJorXnXPZ https://t .
#
# (0.99999999999999967, 0.99938832499374319)
# RT @farmandeMehrdad : # Bahrain slam hypocritical comments by # Iran regime . https://t.co/66cmF3z56O https://t.co/9aGXQEsjsM # MiddleEast # MTP
#
# (0.99999999999999967, 0.99938832499374319)
# RT @moazan45ghj : # Bahrain slam hypocritical comments by # Iran regime . https://t.co/2R6fI1irY5 # MiddleEast # MTP # FNS # Obama # News
#
# (0.99999999999999967, 0.9990377009524799)
# Financial Times : US call for restraint as Saudi - Iran tensions escalate . https://t.co/cwU8VOGbUk   # Sierra # Iran # Hezbollah
#
# (0.99999999999999967, 0.99900645719903436)
# RT @arthurschwartz : say the fake Vietnam combat vet who just vote to give $ 150 billion to Iran . # ValorThief   https://t.co/QAQXxcK3qa
#
# (0.99999999999999967, 0.999251034760959)
# RT @iran_policy : Ahmad Ramazan : # Iran IRGC Gen. Qassem Soleimani say before we will send 100000 forces to Aleppo if need , but they now fac
#
# (0.99999999999999967, 0.99999999999999989)
# RT @wikileaks : The cold war between # Saudi Arabia and # Iran that ' tear apart the Middle East , explain https://t.co/vyoUIDT994
#
# (0.99999999999999967, 0.99915297479655885)
# RT @ABC : New tensions between Iran , Saudi Arabia could have major implications for fight against ISIS https://t.co/d9H0hdPFbT https://t.co/
#
# (0.99999999999999967, 0.99901304573302852)
# RT @GulfStatesInst : Press conference transcript with Saudi FM Abel Al Jubeir on cut ties with Iran https://t.co/97PbPiymx7
#
# (0.99999999999999967, 0.99947995217248198)
# RT @BiafraHerald : Iran : We have use all channels to warn Nigeria over Shiite leader https://t.co/nqLjxSJwx8 https://t.co/RY4tnumVm5
#
# (0.99999999999999967, 0.99935431924312357)
# RT @aliamir1342 : # Iran news in brief https://t.co/lkeHF4mti6   # No2Rouhani # IranFreedom # StopExecutionsIran # HumanRights # terrorism https://
#
# (0.99999999999999967, 0.99933218075542452)
# RT @Ebuka_Mbanefo : We have warn Nigeria to release ZakZaky - Islamic Republic Of Iran - https://t.co/7oBA1G4sYH
#
# (0.99999999999999967, 0.99932876603034504)
# @GtotheTOP8 I better keep my mouth shut since I have a lot to say on Iran , so yeah . let 's change the subject lol
#
# (0.99999999999999967, 0.99930982207740759)
# Bahrain and Sudan sever diplomatic ties with Iran - Financial Times : Financial TimesBahrain and ... https://t.co/sG14ucy7cR # africa # sudan
#
# (0.99999999999999967, 0.99905123470367618)
# Iran 's statements about human rights .
#
# (0.99999999999999967, 0.99924269434172608)
# RT @4FreedominIran : Ahmad Ramazan , # Syria 's democratic opposition : In 2012 Assad saw he could not defeat opposition forces , so # Iran regime
#
# (0.99999999999999967, 0.99918036848800407)
# RT @JRubinBlogger : Obama 's Iran blunder https://t.co/Scsc2Zcss0

# %% [markdown]
# # Part 4: [Bonus] Your Own Analysis
# Build your own analysis using the above twitter data.
# Alternatively, collect your own tweets to analyze following the instructions in `twitter-instructions.md`
